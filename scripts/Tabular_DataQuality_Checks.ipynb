# %%
import os
import time
import datetime
import pandas as pd
import numpy as np
import sys
import matplotlib.pyplot as plt
import seaborn as sns


from sdmetrics.reports.single_table import QualityReport

real_data = pd.read_csv('simple_tabular_data.csv')

#synthetic_data = pd.read_csv('ctgan_generated_simple_tabular_data.csv')
synthetic_data = pd.read_csv('rtf_generated_simple_tabular_data.csv')




real_data.hist(column='age')
plt.title('Histogram of age: Real Data')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

synthetic_data_ctgan.hist(column='age')
plt.title('Histogram of age: Synthetic Data')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %%
sns.countplot(real_data['occupation'], color='gray')
# Out:
# <Axes: xlabel='count', ylabel='occupation'>

# %%
sns.countplot(synthetic_data_ctgan['occupation'], color='blue')
# Out:
# <Axes: xlabel='count', ylabel='occupation'>

# %%
g = sns.FacetGrid(real_data, col="sex", col_wrap=2, height=4)
g.map(sns.scatterplot, "age", "capital-gain")
g.set_axis_labels("Age", "CapitalGain")
g.set_titles("Group {col_name}")
plt.show()

# %%
g = sns.FacetGrid(synthetic_data_ctgan, col="sex", col_wrap=2, height=4)
g.map(sns.scatterplot, "age", "capital-gain")
g.set_axis_labels("Age", "CapitalGain")
g.set_titles("Group {col_name}")
plt.show()
