# %%
import pandas as pd

real_df = pd.read_csv("../data/simple_tabular_data.csv")
syn_df = pd.read_csv("../data/generated_rtf_simple_tabular_data.csv")
test_df = pd.read_csv("../data/simple_tabular_test.csv")

print("Real DataFrame:")
print(real_df.head())
print("\nSynthetic DataFrame:")
print(syn_df.head())
print("\nTest DataFrame:")
print(test_df.head())
# Out:
# Real DataFrame:
#    age  workclass  fnlwgt    education  education-num         marital-status  \
# 0   28    Private   76714  Prof-school             15          Never-married
# 1   41    Private  178431      HS-grad              9     Married-civ-spouse
# 2   53    Private  290640      HS-grad              9     Married-civ-spouse
# 3   31    Private  215297      HS-grad              9     Married-civ-spouse
# 4   34  Local-gov  188682    Bachelors             13  Married-spouse-absent
#
#        occupation   relationship                race     sex  capital-gain  \
# 0  Prof-specialty  Not-in-family               White    Male             0
# 1    Craft-repair        Husband  Asian-Pac-Islander    Male             0
# 2   Other-service        Husband               White    Male             0
# 3    Craft-repair        Husband               White    Male             0
# 4  Prof-specialty  Not-in-family               White  Female             0
#
#    capital-loss  hours-per-week native-country income
# 0             0              55  United-States   >50K
# 1             0              40         Taiwan  <=50K
# 2             0              50        Germany   >50K
# 3             0              45  United-States  <=50K
# 4             0              40  United-States  <=50K
#
# Synthetic DataFrame:
#    age         workclass  fnlwgt  education  education-num  \
# 0   17           Private   55880       11th              7
# 1   37           Private  142249    HS-grad              9
# 2   31           Private  309040  Bachelors             13
# 3   37  Self-emp-not-inc  366502    HS-grad              9
# 4   49           Private  161082    HS-grad              9
#
#        marital-status         occupation relationship   race     sex  \
# 0       Never-married      Other-service    Own-child  White  Female
# 1  Married-civ-spouse       Craft-repair      Husband  White    Male
# 2  Married-civ-spouse    Exec-managerial      Husband  White    Male
# 3  Married-civ-spouse  Handlers-cleaners      Husband  White    Male
# 4           Separated       Adm-clerical    Unmarried  White  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0             0             0              18  United-States  <=50K
# 1             0             0              40  United-States   >50K
# 2          3900             0              40  United-States   >50K
# 3             0             0              40  United-States   >50K
# 4             0             0              40  United-States  <=50K
#
# Test DataFrame:
#    age     workclass  fnlwgt     education  education-num      marital-status  \
# 0   35       Private  191807     Assoc-voc             11  Married-civ-spouse
# 1   43  Self-emp-inc  504423       Masters             14  Married-civ-spouse
# 2   36       Private   48520  Some-college             10            Divorced
# 3   53       Private  221672          12th              8  Married-civ-spouse
# 4   20       Private   95989  Some-college             10       Never-married
#
#         occupation relationship                race     sex  capital-gain  \
# 0     Tech-support      Husband               White    Male             0
# 1  Exec-managerial      Husband  Asian-Pac-Islander    Male             0
# 2    Other-service    Unmarried               White  Female             0
# 3    Other-service      Husband               White    Male             0
# 4            Sales    Own-child               White  Female             0
#
#    capital-loss  hours-per-week native-country  income
# 0             0              40  United-States  <=50K.
# 1             0              60          Japan   >50K.
# 2             0              40  United-States  <=50K.
# 3             0              40  United-States  <=50K.
# 4             0              35  United-States  <=50K.

# %%
from predictor import test_decision_tree, test_svm

print("\nEvaluating SVM:")
print("Using only real data:")
test_svm(real_df, test_df)
print("Using both real and synthetic data:")
test_svm([real_df, syn_df], test_df)

print("\nEvaluating Decision Tree:")
print("Using only real data:")
test_decision_tree(real_df, test_df)
print("Using both real and synthetic data:")
test_decision_tree([real_df, syn_df], test_df)
# Out:
# Evaluating SVM:
# Using only real data:
# Accuracy: 0.8210  (821/1000) rows correct
# Using both real and synthetic data:
# Accuracy: 0.8190  (819/1000) rows correct
#
# Evaluating Decision Tree:
# Using only real data:
# Decision Tree Accuracy: 0.7720  (772/1000) rows correct
# Using both real and synthetic data:
# Decision Tree Accuracy: 0.7780  (778/1000) rows correct
# /home/steven/Projects/generative-trace-tutorials/scripts/predictor.py:32: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
# /home/steven/Projects/generative-trace-tutorials/scripts/predictor.py:32: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
# /home/steven/Projects/generative-trace-tutorials/scripts/predictor.py:111: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
# /home/steven/Projects/generative-trace-tutorials/scripts/predictor.py:111: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
# (Pipeline(steps=[('preprocess',
#                   ColumnTransformer(transformers=[('num', 'passthrough',
#                                                    ['age', 'fnlwgt',
#                                                     'education-num',
#                                                     'capital-gain',
#                                                     'capital-loss',
#                                                     'hours-per-week']),
#                                                   ('cat',
#                                                    OneHotEncoder(handle_unknown='ignore'),
#                                                    ['workclass', 'education',
#                                                     'marital-status',
#                                                     'occupation', 'relationship',
#                                                     'race', 'sex',
#                                                     'native-country'])])),
#                  ('tree', DecisionTreeClassifier(random_state=42))]),
#  0.778,
#  778,
#  1000)
