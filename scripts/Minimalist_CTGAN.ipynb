# %%
import os
import time
import datetime
import pandas as pd
import numpy as np
import sys

from ctgan import CTGAN

# %%
real_data = pd.read_csv('simple_tabular_data.csv')
print(real_data)
# Out:
#      Unnamed: 0  age         workclass  fnlwgt     education  education-num  \
# 0             0   39         State-gov   77516     Bachelors             13
# 1             1   50  Self-emp-not-inc   83311     Bachelors             13
# 2             2   38           Private  215646       HS-grad              9
# 3             3   53           Private  234721          11th              7
# 4             4   28           Private  338409     Bachelors             13
# ..          ...  ...               ...     ...           ...            ...
# 995         995   56           Private  112840       HS-grad              9
# 996         996   45           Private   89325       Masters             14
# 997         997   48       Federal-gov   33109     Bachelors             13
# 998         998   40           Private   82465  Some-college             10
# 999         999   39      Self-emp-inc  329980     Bachelors             13
#
#          marital-status         occupation   relationship   race     sex  \
# 0         Never-married       Adm-clerical  Not-in-family  White    Male
# 1    Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2              Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3    Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4    Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ..                  ...                ...            ...    ...     ...
# 995  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 996            Divorced     Prof-specialty  Not-in-family  White    Male
# 997            Divorced    Exec-managerial      Unmarried  White    Male
# 998  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 999  Married-civ-spouse    Exec-managerial        Husband  White    Male
#
#      capital-gain  capital-loss  hours-per-week native-country income
# 0            2174             0              40  United-States  <=50K
# 1               0             0              13  United-States  <=50K
# 2               0             0              40  United-States  <=50K
# 3               0             0              40  United-States  <=50K
# 4               0             0              40           Cuba  <=50K
# ..            ...           ...             ...            ...    ...
# 995             0             0              55  United-States   >50K
# 996             0             0              45  United-States  <=50K
# 997             0             0              58  United-States   >50K
# 998          2580             0              40  United-States  <=50K
# 999         15024             0              50  United-States   >50K
#
# [1000 rows x 16 columns]

# %%
ctgan = CTGAN(epochs=10,verbose=True)

# %%
# Names of the columns that are discrete
discrete_columns = [
    'workclass',
    'education',
    'marital-status',
    'occupation',
    'relationship',
    'race',
    'sex',
    'native-country',
    'income'
]

ctgan.fit(real_data, discrete_columns)
# Out:
# Epoch 1, Loss G:  2.0559,Loss D: -0.0239
# Epoch 2, Loss G:  2.0825,Loss D: -0.0653
# Epoch 3, Loss G:  2.0989,Loss D: -0.1372
# Epoch 4, Loss G:  2.0674,Loss D: -0.2382
# Epoch 5, Loss G:  2.1038,Loss D: -0.3356
# Epoch 6, Loss G:  1.9584,Loss D: -0.4192
# Epoch 7, Loss G:  1.9625,Loss D: -0.5541
# Epoch 8, Loss G:  1.9944,Loss D: -0.6525
# Epoch 9, Loss G:  1.9869,Loss D: -0.7162
# Epoch 10, Loss G:  1.9030,Loss D: -0.9062

# %%
synthetic_data = ctgan.sample(1000)

# %%
print(synthetic_data)
# Out:
#      Unnamed: 0  age     workclass  fnlwgt     education  education-num  \
# 0           880   30       Private  278448     Assoc-voc              9
# 1           775   27             ?  254300           9th              8
# 2           984   27     State-gov  125535     Bachelors             10
# 3           658   38  Self-emp-inc   30623          10th              9
# 4           614   29       Private  378225       7th-8th             14
# ..          ...  ...           ...     ...           ...            ...
# 995         592   24             ?  182957  Some-college             10
# 996          57   11     Local-gov  559923           9th             12
# 997         433   24       Private  111622     Doctorate             13
# 998         771   30       Private  273124     Bachelors              9
# 999         894   27     Local-gov  114337     Assoc-voc             14
#
#             marital-status         occupation relationship  \
# 0            Never-married     Prof-specialty    Unmarried
# 1                Separated              Sales         Wife
# 2            Never-married      Other-service      Husband
# 3    Married-spouse-absent     Prof-specialty    Own-child
# 4        Married-AF-spouse  Handlers-cleaners      Husband
# ..                     ...                ...          ...
# 995              Separated    Priv-house-serv    Unmarried
# 996     Married-civ-spouse    Exec-managerial      Husband
# 997  Married-spouse-absent  Machine-op-inspct      Husband
# 998              Separated  Machine-op-inspct    Own-child
# 999          Never-married       Tech-support      Husband
#
#                    race     sex  capital-gain  capital-loss  hours-per-week  \
# 0                 White    Male          -134           -39              38
# 1    Asian-Pac-Islander  Female            89           -40              39
# 2    Amer-Indian-Eskimo    Male          -216           -17              41
# 3                 White    Male            30           -42              28
# 4                 Black  Female          -226           -35               3
# ..                  ...     ...           ...           ...             ...
# 995               Black    Male          -114           -17              17
# 996  Asian-Pac-Islander  Female            -8           -21              31
# 997               Black    Male          -222          1893              39
# 998               White    Male         -3144           -18              40
# 999               White    Male           -55           -33               9
#
#     native-country income
# 0           Canada  <=50K
# 1           Poland  <=50K
# 2          Jamaica   >50K
# 3          Germany  <=50K
# 4            Italy   >50K
# ..             ...    ...
# 995         Canada   >50K
# 996        Ecuador  <=50K
# 997          South  <=50K
# 998       Honduras   >50K
# 999    Philippines   >50K
#
# [1000 rows x 16 columns]

# %%
synthetic_data.to_csv('ctgan_generated_simple_tabular_data.csv', index=True)
