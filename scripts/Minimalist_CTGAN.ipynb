# %%
import os
import time
import datetime
import pandas as pd
import numpy as np
import sys

from ctgan import CTGAN

# %%
real_data = pd.read_csv('../data/simple_tabular_data.csv')
print(real_data)
# Out:
#      age         workclass  fnlwgt     education  education-num  \
# 0     39         State-gov   77516     Bachelors             13
# 1     50  Self-emp-not-inc   83311     Bachelors             13
# 2     38           Private  215646       HS-grad              9
# 3     53           Private  234721          11th              7
# 4     28           Private  338409     Bachelors             13
# ..   ...               ...     ...           ...            ...
# 995   56           Private  112840       HS-grad              9
# 996   45           Private   89325       Masters             14
# 997   48       Federal-gov   33109     Bachelors             13
# 998   40           Private   82465  Some-college             10
# 999   39      Self-emp-inc  329980     Bachelors             13
#
#          marital-status         occupation   relationship   race     sex  \
# 0         Never-married       Adm-clerical  Not-in-family  White    Male
# 1    Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2              Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3    Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4    Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ..                  ...                ...            ...    ...     ...
# 995  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 996            Divorced     Prof-specialty  Not-in-family  White    Male
# 997            Divorced    Exec-managerial      Unmarried  White    Male
# 998  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 999  Married-civ-spouse    Exec-managerial        Husband  White    Male
#
#      capital-gain  capital-loss  hours-per-week native-country income
# 0            2174             0              40  United-States  <=50K
# 1               0             0              13  United-States  <=50K
# 2               0             0              40  United-States  <=50K
# 3               0             0              40  United-States  <=50K
# 4               0             0              40           Cuba  <=50K
# ..            ...           ...             ...            ...    ...
# 995             0             0              55  United-States   >50K
# 996             0             0              45  United-States  <=50K
# 997             0             0              58  United-States   >50K
# 998          2580             0              40  United-States  <=50K
# 999         15024             0              50  United-States   >50K
#
# [1000 rows x 15 columns]

# %%
ctgan = CTGAN(epochs=10,verbose=True)

# %%
# Names of the columns that are discrete
discrete_columns = [
    'workclass',
    'education',
    'marital-status',
    'occupation',
    'relationship',
    'race',
    'sex',
    'native-country',
    'income'
]

ctgan.fit(real_data, discrete_columns)
# Out:
# Epoch 1, Loss G:  1.9384,Loss D: -0.0177
# Epoch 2, Loss G:  2.0025,Loss D: -0.0766
# Epoch 3, Loss G:  2.0326,Loss D: -0.1120
# Epoch 4, Loss G:  1.9964,Loss D: -0.2148
# Epoch 5, Loss G:  1.9389,Loss D: -0.2933
# Epoch 6, Loss G:  1.9075,Loss D: -0.3990
# Epoch 7, Loss G:  1.8594,Loss D: -0.5436
# Epoch 8, Loss G:  1.7828,Loss D: -0.6484
# Epoch 9, Loss G:  1.7736,Loss D: -0.7691
# Epoch 10, Loss G:  1.6971,Loss D: -0.7390

# %%
synthetic_data = ctgan.sample(1000)

# %%
print(synthetic_data)
# Out:
#      age     workclass  fnlwgt   education  education-num      marital-status  \
# 0     27     State-gov  298756   Preschool              9  Married-civ-spouse
# 1     23       Private  286896  Assoc-acdm             10  Married-civ-spouse
# 2     57  Self-emp-inc  319289        12th             18            Divorced
# 3     46       Private  -19673     7th-8th             10       Never-married
# 4     41  Self-emp-inc   18693     5th-6th              9  Married-civ-spouse
# ..   ...           ...     ...         ...            ...                 ...
# 995   57             ?   14660     7th-8th              9       Never-married
# 996   17       Private  120181        11th             16   Married-AF-spouse
# 997   58       Private   42091        10th              9       Never-married
# 998   36     Local-gov  153046     HS-grad              8       Never-married
# 999   42  Self-emp-inc  342765   Doctorate             10  Married-civ-spouse
#
#             occupation    relationship                race     sex  \
# 0    Machine-op-inspct  Other-relative  Asian-Pac-Islander    Male
# 1         Craft-repair  Other-relative               White    Male
# 2                Sales         Husband               White  Female
# 3        Other-service       Own-child  Asian-Pac-Islander    Male
# 4      Protective-serv   Not-in-family               White    Male
# ..                 ...             ...                 ...     ...
# 995       Craft-repair   Not-in-family               White    Male
# 996    Exec-managerial         Husband               Other    Male
# 997              Sales  Other-relative               Other    Male
# 998       Adm-clerical   Not-in-family               White  Female
# 999       Adm-clerical       Unmarried               White    Male
#
#      capital-gain  capital-loss  hours-per-week native-country income
# 0             136            25              41       Columbia  <=50K
# 1             227           -31              40              ?  <=50K
# 2            -160            14              39    Puerto-Rico   >50K
# 3            -166           -11              79    Puerto-Rico  <=50K
# 4           11247            -4              56          South  <=50K
# ..            ...           ...             ...            ...    ...
# 995          4186           -11              41           Iran  <=50K
# 996           156          2193              49          China  <=50K
# 997            37             2              39       Thailand   >50K
# 998         14664            18              70          South   >50K
# 999           -93           -11              40           Laos  <=50K
#
# [1000 rows x 15 columns]

# %%
synthetic_data.to_csv('../data/generated_ctgan_simple_tabular_data.csv', index=False)
